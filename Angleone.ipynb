# %%
import requests
import pandas as pd
response = requests.get('https://margincalculator.angelbroking.com/OpenAPI_File/files/OpenAPIScripMaster.json')
angleone = response.json()
df = pd.DataFrame(angleone)
df.to_csv('angleone.csv', index= False)

# %%
df
# Out:
#          token                symbol       name     expiry             strike  \
# 0         6293            GULPOLY-BL    GULPOLY                     -1.000000
# 1        24051            739UK30-SG    739UK30                     -1.000000
# 2         3475            THERMAX-EQ    THERMAX                     -1.000000
# 3         3523             69MZ33-SG     69MZ33                     -1.000000
# 4        17996          PGIMCSR2G-MF  PGIMCSR2G                     -1.000000
# ...        ...                   ...        ...        ...                ...
# 115832  126908      GOLD25MAR78900PE       GOLD  28MAR2025   789000000.000000
# 115833  126383  SILVERM25JUN105500PE    SILVERM  23JUN2025  1055000000.000000
# 115834  126515   SILVERM25JUN84500PE    SILVERM  23JUN2025   845000000.000000
# 115835  126997   SILVERM25FEB94000CE    SILVERM  21FEB2025   940000000.000000
# 115836  127687  SILVERM25FEB102750CE    SILVERM  21FEB2025  1027500000.000000
#
#        lotsize instrumenttype exch_seg    tick_size
# 0            1                     NSE     1.000000
# 1          100                     NSE     1.000000
# 2            1                     NSE     5.000000
# 3          100                     NSE     1.000000
# 4            1                     NSE     1.000000
# ...        ...            ...      ...          ...
# 115832       1         OPTFUT      NCO  5000.000000
# 115833       1         OPTFUT      NCO  5000.000000
# 115834       1         OPTFUT      NCO  5000.000000
# 115835       1         OPTFUT      NCO  5000.000000
# 115836       1         OPTFUT      NCO  5000.000000
#
# [115837 rows x 9 columns]
